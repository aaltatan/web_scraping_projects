# %%
import pandas as pd
import json

# %%
with open("results.jsonl", "r", encoding="utf-8") as file:
    data = (json.loads(line[:-1]) for line in file.readlines())

# %%
df = pd.DataFrame(data)

# %%
df[["category", "subcategory"]] = df.departments.apply(pd.Series).iloc[:, :2]

# %%
df.columns = [header.replace("social-", "") for header in df.columns]

# %%
df = df.drop(["departments"], axis="columns")

# %%
df
# Out:
#                                     title  \
# 0                   Dallah Driving School
# 1               Al-Munqash Driving School
# 2     Alriyadah Driving Education company
# 3                   Dallah Driving School
# 4                    Sharq Driving School
# ...                                   ...
# 2560               King Khalid University
# 2561                         Saud Consult
# 2562         Epic Consulting and Training
# 2563                      Al Nakheel Mall
# 2564                            Mega Mall
#
#                                                location     telephone  \
# 0                  Al Awjam, Safwa 32673, Saudi Arabia   966138160707
# 1         Mecca Road, Al-Muzahmiya 19658, Saudi Arabia   966920024424
# 2      Dist, 7687 King Fahd Rd, King Fahd, Riyadh 12...  966114944555
# 3                       Qami, Taif 26577, Saudi Arabia   966127253350
# 4     Kingdom of Saudi Arabia, Dammam, Al-Rayyan dis...    0133338833
# ...                                                 ...           ...
# 2560               P.O.Box : 960 - Postal Code : 61421   966172418000
# 2561  11451 Ash Shaikh Mubarak As Subah, As Sulimani...  966112837800
# 2562  Al Nada commercial Centre, Al Rabie Kingdom of...  966564277783
# 2563  Exit 9, Al-Imam Saud Ibn Abdul Aziz Branch Rd,...  966920000262
# 2564                   7750, Jazan 82731, Saudi Arabia   966173402000
#
#                           email                                       url  \
# 0                                       https://dallahdrivingschool.sa/en
# 1                                            https://menqash-driving.com/
# 2          info@Alriyadahde.com                  https://alriyadahde.com/
# 3                                         https://dallahdrivingschool.sa/
# 4      sharq.support@iau.edu.sa                   https://sharqschool.sa/
# ...                         ...                                       ...
# 2560             dar@kku.edu.sa  http:// http://www.kku.edu.sa/en/node/22
# 2561        scc@saudconsult.com               https://www.saudconsult.com
# 2562  info@epicconsulting.co.uk           http://www.epicconsulting.co.uk
# 2563
# 2564
#
#                                                    link  \
# 0     https://www.ksa.directory/dallah-driving-schoo...
# 1     https://www.ksa.directory/al-munqash-driving-s...
# 2     https://www.ksa.directory/alriyadah-driving-ed...
# 3     https://www.ksa.directory/dallah-driving-schoo...
# 4     https://www.ksa.directory/sharq-driving-school...
# ...                                                 ...
# 2560  https://www.ksa.directory/king-khalid-universi...
# 2561        https://www.ksa.directory/saud-consult/i/24
# 2562  https://www.ksa.directory/epic-consulting-and-...
# 2563     https://www.ksa.directory/al-nakheel-mall/i/28
# 2564         https://www.ksa.directory/mega-mall/i/1110
#
#                                                facebook  \
# 0                                                   NaN
# 1                                                   NaN
# 2     https://www.facebook.com/AlriyadahDrivingEduca...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2560                                                NaN
# 2561                                                NaN
# 2562  https://www.facebook.com/EPIC.Trainings.Consul...
# 2563                                                NaN
# 2564                                                NaN
#
#                                               instagram  \
# 0                                                   NaN
# 1                                                   NaN
# 2                https://www.instagram.com/alriyadahco/
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2560                https://www.instagram.com/insta_kku
# 2561                                                NaN
# 2562  https://www.instagram.com/epic.trainings.consu...
# 2563                                                NaN
# 2564              https://www.instagram.com/megamall_4/
#
#                                                linkedin  \
# 0                                                   NaN
# 1                                                   NaN
# 2     https://www.linkedin.com/company/alriyadah-dri...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2560                                                NaN
# 2561  https://www.linkedin.com/company/saudi-consult...
# 2562  https://www.linkedin.com/company/epic-training...
# 2563                                                NaN
# 2564                                                NaN
#
#                                   twitter  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4           https://twitter.com/sharq_iau
# ...                                   ...
# 2560        https://twitter.com/kkueduksa
# 2561      https://twitter.com/saudconsult
# 2562  https://twitter.com/epic__trainings
# 2563                                  NaN
# 2564                                  NaN
#
#                                                 youtube  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2560  https://www.youtube.com/channel/UCz5CaPkOMlSgz...
# 2561                                                NaN
# 2562                                                NaN
# 2563                                                NaN
# 2564                                                NaN
#
#                    category                    subcategory
# 0                  Services                 Driving School
# 1                  Services                 Driving School
# 2                  Services                 Driving School
# 3                  Services                 Driving School
# 4                  Services                 Driving School
# ...                     ...                            ...
# 2560              Education                   Universities
# 2561               Services                    Consultants
# 2562              Education  Training Institutes & Centers
# 2563  Tourism & Hospitality                  Shopping Mall
# 2564  Tourism & Hospitality                  Shopping Mall
#
# [2565 rows x 13 columns]
