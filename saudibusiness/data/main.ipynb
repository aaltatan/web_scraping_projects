# %%
import pandas as pd
import numpy as np
import json

# %%
with open("data.jsonl", "r", encoding="utf-8") as file:
    data = (json.loads(line[:-1]) for line in file.readlines())

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                                     name  \
# 0                           حراج الأثاث المستعمل في ابها
# 1      بيع المياه والمرطبات بالخرج | أسماء النقاء في ...
# 2               طلب هب | افضل باركود منيو للمطاعم في جدة
# 3                        شركة المستقبل للخدمات في الرياض
# 4                                 ايدبل أرينجمنتس في جدة
# ...                                                  ...
# 57729               مركز صحى الخدمة الإجتماعية في الرياض
# 57730                    مركز صحى الخالدية في حفر الباطن
# 57731                  مركز صحى الخضر في المدينة المنورة
# 57732               مركز صحى الخالدية في المدينة المنورة
# 57733                        مركز صحى الخالدية في الرياض
#
#                       category   subcategory description       country  \
# 0                حراج السعودية   حراج الأثاث              Saudi Arabia
# 1                      المطاعم  عصيرات طازجة              Saudi Arabia
# 2      الكمبيوتر والإلكترونيات  خدمات انترنت              Saudi Arabia
# 3                حراج السعودية   حراج الأثاث              Saudi Arabia
# 4                      المطاعم        حلويات              Saudi Arabia
# ...                        ...           ...         ...           ...
# 57729      وزارات وجهات حكومية   جهات حكومية              Saudi Arabia
# 57730      وزارات وجهات حكومية   جهات حكومية              Saudi Arabia
# 57731      وزارات وجهات حكومية   جهات حكومية              Saudi Arabia
# 57732      وزارات وجهات حكومية   جهات حكومية              Saudi Arabia
# 57733      وزارات وجهات حكومية   جهات حكومية              Saudi Arabia
#
#                                                  address    telephone fax  \
# 0                                              أبها 2210
# 1      لبيع المياه والمرطبات. 8411 العام ، حي السحاب،...   0532275245
# 2
# 3                                                         01020878825
# 4                                   الزهراء, شارع باترجي  ٦٩٢٧٨٧٨-٠١٢
# ...                                                  ...          ...  ..
# 57729                             المدينة الرياض, الرياض    114463195
# 57730                            حي الخالدية, حفر الباطن    137223151
# 57731                           المدينة, المدينة المنورة    148231876
# 57732                           المدينة, المدينة المنورة    148485316
# 57733                                     الزلفي, الرياض    114222735
#
#                         website  \
# 0
# 1
# 2          https://talabhub.com
# 3      https://al-mostakbl.com/
# 4
# ...                         ...
# 57729
# 57730
# 57731
# 57732
# 57733
#
#                                         google_maps_link  \
# 0      http://maps.google.com/maps?q=%D8%A3%D8%A8%D9%...
# 1      http://maps.google.com/maps?q=%D9%84%D8%A8%D9%...
# 2      http://maps.google.com/maps?q=%20%20%20%20Saud...
# 3      http://maps.google.com/maps?q=%20%20%20%20Saud...
# 4      http://maps.google.com/maps?q=%D8%A7%D9%84%D8%...
# ...                                                  ...
# 57729  http://maps.google.com/maps?q=%D8%A7%D9%84%D9%...
# 57730  http://maps.google.com/maps?q=%D8%AD%D9%8A%20%...
# 57731  http://maps.google.com/maps?q=%D8%A7%D9%84%D9%...
# 57732  http://maps.google.com/maps?q=%D8%A7%D9%84%D9%...
# 57733  http://maps.google.com/maps?q=%D8%A7%D9%84%D8%...
#
#                                                      url
# 0      https://saudibusiness.directory/%D8%AD%D8%B1%D...
# 1      https://saudibusiness.directory/%D8%A8%D9%8A%D...
# 2      https://saudibusiness.directory/%D8%B7%D9%84%D...
# 3      https://saudibusiness.directory/%D8%B4%D8%B1%D...
# 4      https://saudibusiness.directory/%D8%A7%D9%8A%D...
# ...                                                  ...
# 57729  https://saudibusiness.directory/%D9%85%D8%B1%D...
# 57730  https://saudibusiness.directory/%D9%85%D8%B1%D...
# 57731  https://saudibusiness.directory/%D9%85%D8%B1%D...
# 57732  https://saudibusiness.directory/%D9%85%D8%B1%D...
# 57733  https://saudibusiness.directory/%D9%85%D8%B1%D...
#
# [57734 rows x 11 columns]
