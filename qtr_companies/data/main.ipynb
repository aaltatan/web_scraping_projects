# %%
import pandas as pd
import numpy as np
import json
import re

# %%
with open('results.jsonl', 'r', encoding='utf-8') as file:
    data = (json.loads(line[:-1]) for line in file.readlines())

# %%
df = pd.DataFrame(data)

# %%
df = df[[
    'اسم الشركة',
    'website',
    'وصف الشركة',
    'عنوان الشركة',
    'الهاتف',
    'email',
    'المدينة',
    'القسم',
    'تاريخ الإضافة:',
    'إتصل',
    'واتس أب',
    'عبر الهاتف',
    'رسالة عبر الأيميل',
    # 'link',
]]

# %%
df.drop_duplicates(inplace=True)

# %%
df.columns = [
    'title',
    'website',
    'description',
    'address',
    'phone',
    'email',
    'city',
    'category',
    'add_date',
    'phone_2',
    'whatsapp',
    'phone_3',
    'email_2',
    # 'link',
]

# %%
def cf_decode_email(encodedString):
    r = int(encodedString[:2], 16)
    email = ''.join([chr(int(encodedString[i:i+2], 16) ^ r)
                    for i in range(2, len(encodedString), 2)])
    return email

# %%
def parse_email(email):
    if type(email) == str:
        enc_email = email.split('#')[-1]
        return cf_decode_email(enc_email)
    else:
        return email

# %%
df['email_2'] = df['email_2'].apply(parse_email)

# %%
df['whatsapp'] = df['whatsapp'].str.extract(r'(\d+)')

# %%
df['phone_2'] = df['phone_2'].str.extract(r'(\d+)')

# %%
df['phone_3'] = df['phone_3'].str.extract(r'(\d+)')

# %%
phones_df = df['phone'].apply(lambda x: re.compile(
    r'\d{4}\s?\d{4}\b').findall(str(x))).apply(pd.Series)

# %%
phones_df.dropna(thresh=len(phones_df)*0.1, axis='columns', inplace=True)

# %%
phones_df.columns = ['phone_e_1', 'phone_e_2', 'phone_e_3']

# %%
phones_df['phone_e_1'] = phones_df['phone_e_1'].str.replace(' ',
                                                            '',
                                                            regex=True)
phones_df['phone_e_2'] = phones_df['phone_e_2'].str.replace(' ',
                                                            '',
                                                            regex=True)
phones_df['phone_e_3'] = phones_df['phone_e_2'].str.replace(' ',
                                                            '',
                                                            regex=True)

# %%
df = pd.concat([df, phones_df], axis='columns')

# %%
df['email'].replace(np.nan, '', inplace=True)

# %%
df['email_final'] = df.apply(lambda x: x['email_2'] if x['email'] == '' else x['email'],
                             axis='columns')

# %%
df.drop(columns=['email', 'email_2'], inplace=True)
df.rename({'email_final': 'email'}, inplace=True, axis='columns')

# %%
df = df[[
    'title',
    'category',
    'description',
    'city',
    'address',
    'email',
    'website',
    'whatsapp',
    'phone_2',
    'phone_3',
    'phone_e_1',
    'phone_e_2',
    'phone_e_3',
    'phone',
    'add_date',
    # 'link',
]]

# %%
df.rename({
    'phone_2': 'phone_1',
    'phone_3': 'phone_2',
    'phone_e_1': 'phone_3',
    'phone_e_2': 'phone_4',
    'phone_e_3': 'phone_5',
    'phone': 'other_contact_details',
}, axis='columns', inplace=True)

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#                                                    title  \
# 0                                       جست جيم Just-Gym
# 1                                     Ali Bin Ali Travel
# 2                                Rosabella_Beauty Center
# 3                                          Qatar Factory
# 4                                Contour Boutique Saloon
# ...                                                  ...
# 78588                    OSOUL TRADING & CONTRACTING WLL
# 78589  TECHNICAL DEVELOPMENT OF ELECTRO MECHANICAL CO...
# 78590                                  AL AREEKAH CO WLL
# 78591     WHITE STROK TRADING CONTRACTING & CLEANING WLL
# 78592                         TAKAMUL PROJECT MANAGEMENT
#
#                              category  \
# 0              شركات الاجهزة الرياضية
# 1                شركات السياحة والسفر
# 2               مراكز صالونات التجميل
# 3       شركات الأمن وكاميرات المراقبة
# 4               مراكز صالونات التجميل
# ...                               ...
# 78588                 شركات المقاولات
# 78589                 شركات المقاولات
# 78590                 شركات المقاولات
# 78591                 شركات المقاولات
# 78592                 شركات المقاولات
#
#                                              description     city  \
# 0                                       جست جيم Just-Gym   الدوحة
# 1      Ali Bin Ali Travel, Tourism &amp; Cargo divisi...   الدوحة
# 2      DIVE INTO THE WORLD OF BEAUTY\r\nYOUR BEAUTY O...   الدوحة
# 3      Fire Protection is a way of life for QATAR FAC...   الدوحة
# 4      Contour Boutique offers world-class hair dress...   الدوحة
# ...                                                  ...      ...
# 78588                                       construction   الدوحة
# 78589                                       construction   الدوحة
# 78590                                       construction   الدوحة
# 78591                                       construction   الدوحة
# 78592                                       construction   الدوحة
#
#                                                  address  \
# 0              جست,جيم,,Al,Sad,Sports,Club,,Al,Wa'ab,st.
# 1      Al Sadd, Al Sadd Commercial Center - Al Sadd s...
# 2                     Zkreet 595 , Al Khuraytiyat, Qatar
# 3      Building No 195, Zone 81, Street 23 K, New, Do...
# 4                                            Doha, Qatar
# ...                                                  ...
# 78588                                               doha
# 78589                                               doha
# 78590                                               doha
# 78591                                               doha
# 78592                                               doha
#
#                                 email  \
# 0           reception@mtmgroup.com.qa
# 1                travel@alibinali.com
# 2            Rosabellaqatar@gmail.com
# 3                info@qatarfactory.qa
# 4       contourboutiquedoha@gmail.com
# ...                               ...
# 78588             osoul2016@gmail.com
# 78589              mohammad.a@tdec.qa
# 78590              info@alareekah.com
# 78591               wstorkq@gmail.com
# 78592  mohammed.jaseem@takamul-pm.com
#
#                                                  website     whatsapp  \
# 0      https://www.facebook.com/Just-Gym-119294094816336          NaN
# 1                       https://www.alibinalitravel.com/  97444441161
# 2      https://rosabella-beauty-center.business.site/...  97450910153
# 3                            http://www.qatarfactory.qa/  97444114630
# 4            https://contourbotiquedoha.wixsite.com/main  97450960456
# ...                                                  ...          ...
# 78588                              http://www.dirqtr.com          NaN
# 78589                                http://www.tdec.qa/          NaN
# 78590                          http://www.alareekah.com/          NaN
# 78591                              http://www.dirqtr.com          NaN
# 78592                         http://www.takamul-pm.com/          NaN
#
#            phone_1      phone_2   phone_3   phone_4   phone_5  \
# 0              NaN          NaN  44594211       NaN       NaN
# 1      97444441161  97444441161       NaN       NaN       NaN
# 2      97450910153  97450910153       NaN       NaN       NaN
# 3      97444114630  97444025888       NaN       NaN       NaN
# 4      97450960456  97450960456       NaN       NaN       NaN
# ...            ...          ...       ...       ...       ...
# 78588          NaN          NaN  66553859       NaN       NaN
# 78589          NaN          NaN  44171663  33171778  33171778
# 78590          NaN          NaN  44602219  55835230  55835230
# 78591          NaN          NaN  33031270       NaN       NaN
# 78592          NaN          NaN  40376039  33556926  33556926
#
#           other_contact_details    add_date
# 0                   97444594211    1/1/2019
# 1                           NaN   24/5/2023
# 2                           NaN   20/6/2023
# 3                           NaN    7/6/2023
# 4                           NaN   20/6/2023
# ...                         ...         ...
# 78588            Phone 66553859   9/10/2018
# 78589   Phone 44171663 33171778   9/10/2018
# 78590         44602219 55835230  13/10/2018
# 78591            Phone 33031270   9/10/2018
# 78592  Phones 40376039 33556926   9/10/2018
#
# [78593 rows x 15 columns]
