# %%
import pandas as pd
import json

# %%
with open('./data.jsonl', 'r', encoding='utf-8') as file:
    data = (json.loads(line[:-1]) for line in file.readlines())

# %%
df = pd.json_normalize(data)

# %%
df.columns
# Out:
# Index(['id', 'product_class', 'sku', 'barcode', 'parent_id', 'name', 'slug',
#        'price', 'short_description', 'sale_price', 'formatted_price',
#        'formatted_sale_price', 'currency', 'currency_symbol', 'attributes',
#        'categories', 'display_order', 'has_options', 'has_fields', 'images',
#        'is_draft', 'quantity', 'is_infinite', 'html_url', 'keywords',
#        'requires_shipping', 'is_taxable', 'structure', 'store_id',
#        'metafields', 'meta', 'related_products_settings',
#        'related_products_title', 'badge', 'group_products', 'stocks',
#        'sold_products_count', 'created_at', 'updated_at', 'weight.value',
#        'weight.unit', 'seo.title', 'seo.description', 'rating.average',
#        'rating.total_count', 'rating.1_ratings.percentage',
#        'rating.1_ratings.count', 'rating.2_ratings.percentage',
#        'rating.2_ratings.count', 'rating.3_ratings.percentage',
#        'rating.3_ratings.count', 'rating.4_ratings.percentage',
#        'rating.4_ratings.count', 'rating.5_ratings.percentage',
#        'rating.5_ratings.count', 'purchase_restrictions.min_quantity_per_cart',
#        'purchase_restrictions.max_quantity_per_cart',
#        'purchase_restrictions.availability_period_start',
#        'purchase_restrictions.availability_period_end'],
#       dtype='object')

# %%
df.describe()
# Out:
#              price   sale_price  display_order      quantity  store_id  \
# count  5838.000000  1165.000000    5838.000000  5.838000e+03    5838.0
# mean     34.969637    37.135416   32340.059096  7.357015e+05   52536.0
# std      62.039284    33.244469    3709.415441  5.621184e+07       0.0
# min       0.850000     1.500000       2.000000  0.000000e+00   52536.0
# 25%      14.000000    15.500000   32766.000000  3.000000e+00   52536.0
# 50%      23.000000    25.000000   32766.000000  6.000000e+00   52536.0
# 75%      43.250000    48.500000   32766.000000  1.200000e+01   52536.0
# max    4025.000000   305.000000   32767.000000  4.294967e+09   52536.0
#
#        sold_products_count  weight.value  rating.average  rating.total_count  \
# count          3204.000000        1942.0     5838.000000         5838.000000
# mean            105.250936           0.0        1.089637            0.543337
# std             462.909893           0.0        2.062800            2.252767
# min               9.000000           0.0        0.000000            0.000000
# 25%              15.000000           0.0        0.000000            0.000000
# 50%              29.000000           0.0        0.000000            0.000000
# 75%              70.000000           0.0        0.000000            0.000000
# max           19507.000000           0.0        5.000000           86.000000
#
#        rating.1_ratings.percentage  rating.1_ratings.count  \
# count                       5838.0                  5838.0
# mean                           0.0                     0.0
# std                            0.0                     0.0
# min                            0.0                     0.0
# 25%                            0.0                     0.0
# 50%                            0.0                     0.0
# 75%                            0.0                     0.0
# max                            0.0                     0.0
#
#        rating.2_ratings.percentage  rating.2_ratings.count  \
# count                       5838.0                  5838.0
# mean                           0.0                     0.0
# std                            0.0                     0.0
# min                            0.0                     0.0
# 25%                            0.0                     0.0
# 50%                            0.0                     0.0
# 75%                            0.0                     0.0
# max                            0.0                     0.0
#
#        rating.3_ratings.percentage  rating.3_ratings.count  \
# count                  5838.000000             5838.000000
# mean                      0.008565                0.000171
# std                       0.654392                0.013088
# min                       0.000000                0.000000
# 25%                       0.000000                0.000000
# 50%                       0.000000                0.000000
# 75%                       0.000000                0.000000
# max                      50.000000                1.000000
#
#        rating.4_ratings.percentage  rating.4_ratings.count  \
# count                  5838.000000             5838.000000
# mean                      0.132146                0.003768
# std                       2.859102                0.061277
# min                       0.000000                0.000000
# 25%                       0.000000                0.000000
# 50%                       0.000000                0.000000
# 75%                       0.000000                0.000000
# max                     100.000000                1.000000
#
#        rating.5_ratings.percentage  rating.5_ratings.count  \
# count                  5838.000000             5838.000000
# mean                     21.681831                0.539397
# std                      41.145096                2.234744
# min                       0.000000                0.000000
# 25%                       0.000000                0.000000
# 50%                       0.000000                0.000000
# 75%                       0.000000                0.000000
# max                     100.000000               85.000000
#
#        purchase_restrictions.max_quantity_per_cart
# count                                    13.000000
# mean                                      1.692308
# std                                       1.702186
# min                                       1.000000
# 25%                                       1.000000
# 50%                                       1.000000
# 75%                                       1.000000
# max                                       6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5838 entries, 0 to 5837
# Data columns (total 59 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   id                                               5838 non-null   object
#  1   product_class                                    0 non-null      object
#  2   sku                                              5838 non-null   object
#  3   barcode                                          5838 non-null   object
#  4   parent_id                                        0 non-null      object
#  5   name                                             5838 non-null   object
#  6   slug                                             5838 non-null   object
#  7   price                                            5838 non-null   float64
#  8   short_description                                5788 non-null   object
#  9   sale_price                                       1165 non-null   float64
#  10  formatted_price                                  5838 non-null   object
#  11  formatted_sale_price                             1165 non-null   object
#  12  currency                                         5838 non-null   object
#  13  currency_symbol                                  5838 non-null   object
#  14  attributes                                       5838 non-null   object
#  15  categories                                       5838 non-null   object
#  16  display_order                                    5838 non-null   int64
#  17  has_options                                      5838 non-null   bool
#  18  has_fields                                       5838 non-null   bool
#  19  images                                           5838 non-null   object
#  20  is_draft                                         5838 non-null   bool
#  21  quantity                                         5838 non-null   int64
#  22  is_infinite                                      5838 non-null   bool
#  23  html_url                                         5838 non-null   object
#  24  keywords                                         5838 non-null   object
#  25  requires_shipping                                5838 non-null   bool
#  26  is_taxable                                       5838 non-null   bool
#  27  structure                                        5838 non-null   object
#  28  store_id                                         5838 non-null   int64
#  29  metafields                                       5838 non-null   object
#  30  meta                                             0 non-null      object
#  31  related_products_settings                        5838 non-null   object
#  32  related_products_title                           0 non-null      object
#  33  badge                                            0 non-null      object
#  34  group_products                                   0 non-null      object
#  35  stocks                                           5838 non-null   object
#  36  sold_products_count                              3204 non-null   float64
#  37  created_at                                       5838 non-null   object
#  38  updated_at                                       5838 non-null   object
#  39  weight.value                                     1942 non-null   float64
#  40  weight.unit                                      5838 non-null   object
#  41  seo.title                                        5838 non-null   object
#  42  seo.description                                  5838 non-null   object
#  43  rating.average                                   5838 non-null   float64
#  44  rating.total_count                               5838 non-null   int64
#  45  rating.1_ratings.percentage                      5838 non-null   int64
#  46  rating.1_ratings.count                           5838 non-null   int64
#  47  rating.2_ratings.percentage                      5838 non-null   int64
#  48  rating.2_ratings.count                           5838 non-null   int64
#  49  rating.3_ratings.percentage                      5838 non-null   int64
#  50  rating.3_ratings.count                           5838 non-null   int64
#  51  rating.4_ratings.percentage                      5838 non-null   float64
#  52  rating.4_ratings.count                           5838 non-null   int64
#  53  rating.5_ratings.percentage                      5838 non-null   float64
#  54  rating.5_ratings.count                           5838 non-null   int64
#  55  purchase_restrictions.min_quantity_per_cart      0 non-null      object
#  56  purchase_restrictions.max_quantity_per_cart      13 non-null     float64
#  57  purchase_restrictions.availability_period_start  0 non-null      object
#  58  purchase_restrictions.availability_period_end    0 non-null      object
# dtypes: bool(6), float64(8), int64(12), object(33)
# memory usage: 2.4+ MB

# %%
df.to_excel('data.xlsx')
