# %%
import pandas as pd
import numpy as np
import json

# %%
with open('data.jsonl', 'r', encoding='utf-8') as file:
    data = (json.loads(line[:-1]) for line in file.readlines())

# %%
df = pd.DataFrame(data)

# %%
print(df.shape)
df.head()
# Out:
# (317893, 15)
#                                                 name           city  \
# 0  AL MASHHOUR PASSENGERS TRANSPORT BY RENTAL BUS...  Umm Al Quwain
# 1                 ABM EPOXY FLOORING - Umm Al Quwain  Umm Al Quwain
# 2     AMCO APPAREL MANUFACTURING FZC - Umm Al Quwain  Umm Al Quwain
# 3          OnTides International FZC - Umm Al Quwain  Umm Al Quwain
# 4                Dubai Desert Safari - Umm Al Quwain  Umm Al Quwain
#
#                 category       manager               phone  \
# 0           Buses Rental     Razi Khan         055 4230100
# 1   Building Maintenance  Mohd. Hosain       +971569082477
# 2  Uniform Manufacturing    Eid Kamran   (+971 4) 319 7311
# 3            Engineering    DilipKumar       0097167413998
# 4                Leasing                +971 (0) 429 56223
#
#                 mobile            fax  \
# 0          050 7470016           None
# 1        +971569082477           None
# 2    (+971 50) 6264243           None
# 3       00971561720220  0097167413998
# 4  +971 (0) 508 874754           None
#
#                                       website  \
# 0           http://www.almashhourtransport.ae
# 1  https://uae.storat.com/store/tamim-s-store
# 2                          http://www.amco.ae
# 3                      http://www.ontides.com
# 4             https://www.closedbusiness.com/
#
#                                             location  \
# 0                    Um Al Quwian UAE, Umm Al Quwain
# 1                 Umm Al Quwain , Umm Al Quwain, UAE
# 2  Level 41, Emirates Towers, Sheikh Zayed Road, ...
# 3  Post Box 3706, Umm Al Quwain Free Trade ZOne, ...
# 4           United Arab Emirates, Umm Al Quwain, UAE
#
#                                             products employees  \
# 0
# 1  Warehouse Epoxy Flooring , Car Parking Epoxy F...
# 2                    Outerwear, Casualwear, Workwear
# 3  Cable Roller, Cable Drum Lifting Jacks, Pipe R...
# 4  MUSANDAM DIBBA CRUISE, ABU DHABI & FERRARI WOR...
#
#                                          google_maps  \
# 0  https://maps.google.com/maps?daddr=25.49906604...
# 1  https://maps.google.com/maps?daddr=25.55674041...
# 2  https://maps.google.com/maps?daddr=25.59312629...
# 3  https://maps.google.com/maps?daddr=25.41904313...
# 4  https://maps.google.com/maps?daddr=25.271139,5...
#
#                                          description  \
# 0  We specialize in all types of bus rental servi...
# 1  Dear Sir- Madam, Good day, I will offer you we...
# 2  Amco Apparel Manufacturing Company is the lead...
# 3  We, the OnTides International FZC, would like ...
# 4  closedbusiness closedbusiness closedbusiness c...
#
#                                                 tags  \
# 0  Buses Rental, buses for rent, Buses Rental Com...
# 1  Building Maintenance, Property Maintenance, 3D...
# 2  Uniform Manufacturing, Garment Factory in UAE,...
# 3  Engineering, Industrial Equipment, Industrial ...
# 4                                            Leasing
#
#                                                  url
# 0  https://www.yello.ae/company/358741/al-mashhou...
# 1  https://www.yello.ae/company/373386/abm-epoxy-...
# 2  https://www.yello.ae/company/365121/amco-appar...
# 3  https://www.yello.ae/company/350209/ontides-in...
# 4  https://www.yello.ae/company/354360/dubai-dese...

# %%
df.to_excel('data.xlsx')
