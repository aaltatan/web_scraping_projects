# %%
import pandas as pd

# %%
import json

# %%
with open('./data.jsonl', 'r', encoding='utf-8') as file:
    data = (json.loads(line[:-1]) for line in file.readlines())

# %%
df = pd.json_normalize(data)

# %%
print(df.shape)
df.head()
# Out:
# (4871, 135)
#                                      id product_class            sku barcode  \
# 0  9fa7cbaf-071b-4b51-92be-61b40c1100a5          None  6003016684510
# 1  fd32225a-66c9-4973-bb99-4549f26948f7          None  6287029920920
# 2  eb552645-0663-40d4-bfc9-181bc7a09137          None  6253504708635
# 3  f63b244e-fb03-4623-bdac-6973023069bb          None  1230222920018
# 4  4f2cb989-f70f-4330-9728-e5d50240d63e          None  6287029922832
#
#   parent_id                                               name  \
# 0      None              بيور بلانتا محلول واقي الاظافر 1000مل
# 1      None  DYM 10 |  أحمر شفاه ليف سائل مخملي مطفي يدوم ل...
# 2      None  لوشن المساج تبييض وتنعيم بخلاصة الافندر و جوجو...
# 3      None  بلسم للشفاه  ليف  بلمسه لونيه مشرقه وصحيه | ج ...
# 4      None                                  ظلال عيون ليف -92
#
#                                                 slug  price  \
# 0              بيور-بلانتا-محلول-واقي-الاظافر-1000مل   27.0
# 1  dym-10-أحمر-شفاه-ليف-سائل-مخملي-مطفي-يدوم-ل-8-...   26.0
# 2  لوشن-المساج-تبييض-وتنعيم-بخلاصة-الافندر-و-جوجو...    7.0
# 3  بلسم-للشفاه-ليف-بلمسه-لونيه-مشرقه-وصحيه-ج-bric...   23.0
# 4                                   ظلال-عيون-ليف-92    9.0
#
#                                    short_description  sale_price  ...  \
# 0                                               None         NaN  ...
# 1  احمر شفاه قوامه سائل وبعد ان يجف يصبح مطفي تما...         NaN  ...
# 2  تركيبة لطيفة وخفيفة توفر الترطيب للبشرة الجافة...         NaN  ...
# 3  بلسم معالج وملمع للشفاه جديد ومريح ينساب بسهول...         NaN  ...
# 4                                               None         NaN  ...
#
#   selected_product.discount selected_product.discount_percentage  \
# 0                       NaN                                  NaN
# 1                       NaN                                  NaN
# 2                       NaN                                  NaN
# 3                       NaN                                  NaN
# 4                       NaN                                  NaN
#
#   selected_product.has_custom_user_input_fields  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#   selected_product.has_custom_option_fields  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#   selected_product.has_custom_input_fields selected_product.product_type  \
# 0                                    False                          None
# 1                                    False                          None
# 2                                    False                          None
# 3                                    False                          None
# 4                                    False                          None
#
#    seo.title  seo.description  selected_product.seo.title  \
# 0        NaN              NaN                         NaN
# 1        NaN              NaN                         NaN
# 2        NaN              NaN                         NaN
# 3        NaN              NaN                         NaN
# 4        NaN              NaN                         NaN
#
#   selected_product.seo.description
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
# [5 rows x 135 columns]

# %%
df.columns
# Out:
# Index(['id', 'product_class', 'sku', 'barcode', 'parent_id', 'name', 'slug',
#        'price', 'short_description', 'sale_price',
#        ...
#        'selected_product.discount', 'selected_product.discount_percentage',
#        'selected_product.has_custom_user_input_fields',
#        'selected_product.has_custom_option_fields',
#        'selected_product.has_custom_input_fields',
#        'selected_product.product_type', 'seo.title', 'seo.description',
#        'selected_product.seo.title', 'selected_product.seo.description'],
#       dtype='object', length=135)
