# %%
import pandas as pd
import numpy as np
import json

# %%
cols_to_delete = [
    "sub",
    "imageUrl",
    "totalReviews",
    "certificationStatus",
    "activeStatus",
    "adminActiveStatus",
    "ownerAllowStatus",
    "freeLanceDocument",
    "encryptedId",
    "qrCodeUrl",
    "id",
]

social_media = [
    "Facebook",
    "Instagram",
    "Unknown",
    "Twitter",
    "Unknown",
    "AppStore",
    "PlayStore",
    "Whatsapp",
    "Telegram",
    "Website",
    "Unknown",
    "TikTok",
    "Unknown",
    "Unknown",
    "Unknown",
    "Unknown",
    "Unknown",
    "Unknown",
]

# %%
def generate_data():
    with open("new_data.jsonl", "r", encoding="utf-8") as file:
        for line in file.readlines():
            product = json.loads(line[:-1])
            for col in cols_to_delete:
                product.pop(col)
            consoles = product.pop("consoles")
            socials = {}
            if consoles:
                for c in consoles:
                    socials[social_media[c["providerType"]]] = c["url"]
                product["socialMedia"] = socials
            yield product

# %%
data = generate_data()

# %%
df = pd.json_normalize(data)

# %%
df.replace(r"\.{2,}", "", regex=True, inplace=True)

# %%
import re
from typing import List

# %%
def camel_to_title(string: str) -> str:
    pattern = re.compile(r"([A-z][a-z]+)")
    array = string.split(".")
    words = []
    for w in array:
        matches: List[str] = pattern.findall(w)
        for word in matches:
            word = word.title()
            words.append(word)

    return " ".join(words)

# %%
df.drop_duplicates(inplace=True)

# %%
df.dropna(thresh=2000, axis="columns", inplace=True)

# %%
df[df["businessType.name"] == "Real estate"]
# Out:
#                                      userId  \
# 238    34b269c4-c8c0-4c43-9fc2-dbdbf3c4c318
# 404    1e2bdfa9-d009-4881-ab1f-28b5c167348c
# 473    5cbffccd-0318-4261-aae4-30ff81430a9e
# 591    5cbffccd-0318-4261-aae4-30ff81430a9e
# 754    605bcdb2-7778-4a9a-8a8d-7b2d8e5b0cd6
# ...                                     ...
# 48611  979e2ea0-51de-49da-9f0c-07cb2a43a74a
# 48626  379aece9-56d3-48d0-b015-39dc6e9421a7
# 48707  5a546f82-7a08-48a8-9bec-838977fd5ee6
# 48795  a2554351-886e-47ae-b8f8-a203d50d4525
# 48982  71d415d2-032d-4b00-967a-76241d225e8a
#
#                                          nameAr  \
# 238                       مجموعة هتيلز الفندقية
# 404                     مكتب ابراج عسير العقاري
# 473               مكتب حسن هادي للتقييم العقاري
# 591    المسكان العقارية لتقديم الخدمات العقارية
# 754                       ثريا للوساطة العقارية
# ...                                         ...
# 48611                             وصول العقارية
# 48626         مكتب عالم السماسرة لادارة الاملاك
# 48707                   موارد الانماء العقارية
# 48795                      أساس للتطوير العقاري
# 48982              شركة هيكلة للخدمات العقارية
#
#                                           nameEn  \
# 238                                 Hotelz Group
# 404                                  Abraj Assir
# 473                       Real estate evaluation
# 591    AlMouskan to provide real estate services
# 754                                      THURAYA
# ...                                          ...
# 48611                          Wsool Real Estate
# 48626                                       None
# 48707               mawarid alainama real estate
# 48795               ASAS Real Estate Development
# 48982              haykalah real estate services
#
#                                              description  rating  \
# 238    مجموعة فندقية في مكة المكرمة بجوار الحرم المكي...     5.0
# 404    وسيط معتمد لدى شبكة ايجار \n توثيق عقود ايجار ...     5.0
# 473    التقييم العقاري المعتمد والدراسات والاستشارات ...     5.0
# 591    تقديم الخدمات العقارية باحترافية بيع وشراء وتأ...     5.0
# 754    مؤسسة مختصة بالوساطة العقارية وتقديم الخدمات ا...     5.0
# ...                                                  ...     ...
# 48611          إدارة الأملاك العقارية والتسويق والوساطة      0.0
# 48626                     وساطة بيع ونقل وادارة العقارات     0.0
# 48707                       تسويق و إدارة جميع العقارات      0.0
# 48795  تقديم الحلول العقاري بأكملها و تشمل \r\n دراسة...     0.0
# 48982  شركة هيكلة للخدمات العقارية شركة شخص واحد حاصل...     0.0
#
#       otherTypeName businessType.name businessType.key  businessType.id  \
# 238            None       Real estate       RealEstate               48
# 404            None       Real estate       RealEstate               48
# 473            None       Real estate       RealEstate               48
# 591            None       Real estate       RealEstate               48
# 754            None       Real estate       RealEstate               48
# ...             ...               ...              ...              ...
# 48611          None       Real estate       RealEstate               48
# 48626          None       Real estate       RealEstate               48
# 48707          None       Real estate       RealEstate               48
# 48795          None       Real estate       RealEstate               48
# 48982          None       Real estate       RealEstate               48
#
#       businessSubType.name  ...                      socialMedia.Website  \
# 238                  Other  ...                      www.HotelzGroup.com
# 404     Real estate broker  ...     https://wa.me/message/7J5LHWYFXTX7G1
# 473                  Other  ...    https://www.facebook.com/hassan.h.999
# 591                  Other  ...  https://www.facebook.com/-431203090385/
# 754     Real estate broker  ...                                      NaN
# ...                    ...  ...                                      ...
# 48611                Other  ...                                      NaN
# 48626                Other  ...                                      NaN
# 48707                Other  ...   https://amawarid.business.site/?m=true
# 48795                Other  ...                                      NaN
# 48982   Real estate broker  ...     https://www.haykalah-re.com/homepage
#
#         cr.number                                    cr.name  \
# 238    4031086792                           شركة زي الفندقية
# 404    5855045843                    مكتب أبراج عسير العقاري
# 473    4030370562    مكتب حسن هادي علي حدادي للتقييم العقاري
# 591    4030161502                     مؤسسة المسكان العقارية
# 754           NaN                                        NaN
# ...           ...                                        ...
# 48611  1010671695                        مؤسسة وصول العقارية
# 48626  1131316436          مكتب عالم السماسرة لادارة الأملاك
# 48707  4030411230               مؤسسة موارد الانماء العقارية
# 48795  4030266492         مؤسسة أساس البداية للتطوير العقاري
# 48982  4030318492  شركة هيكلة للخدمات العقارية شركة شخص واحد
#
#                        socialMedia.Twitter  \
# 238        https://twitter.com/HotelzGroup
# 404        https://twitter.com/abraj_3ssir
# 473        https://twitter.com/hassan01985
# 591          https://twitter.com/almouskan
# 754       https://twitter.com/GhareebStore
# ...                                    ...
# 48611  https://twitter.com/wsoolRealestate
# 48626                                  NaN
# 48707         https://twitter.com/3mawarid
# 48795                                  NaN
# 48982      https://twitter.com/haykalah_re
#
#                       socialMedia.Instagram  \
# 238       https://instagram.com/hotelzgroup
# 404    https://www.instagram.com/abraj3ssir
# 473                                     NaN
# 591                                     NaN
# 754                                     NaN
# ...                                     ...
# 48611                                   NaN
# 48626    https://instagram.com/nadiaaleairy
# 48707        https://instagram.com/3mawarid
# 48795                                   NaN
# 48982     https://instagram.com/haykalah.re
#
#                                     socialMedia.Facebook  \
# 238                                                  NaN
# 404                                                  NaN
# 473                                                  NaN
# 591    https://www.facebook.com/profile.php?id=100000...
# 754                                                  NaN
# ...                                                  ...
# 48611                                                NaN
# 48626                                                NaN
# 48707                  https://www.facebook.com/3mawarid
# 48795                                                NaN
# 48982                                                NaN
#
#        address.district.name  address.district.id  \
# 238                      NaN                  NaN
# 404                 al wahah                941.0
# 473                      NaN                  NaN
# 591                      NaN                  NaN
# 754               al andalus                 84.0
# ...                      ...                  ...
# 48611                    NaN                  NaN
# 48626                    NaN                  NaN
# 48707                    NaN                  NaN
# 48795                    NaN                  NaN
# 48982              ash shati                715.0
#
#                                socialMedia.TikTok socialMedia.Unknown
# 238                                           NaN                 NaN
# 404              https://www.tiktok.com/@ejar_sa1                 NaN
# 473                                           NaN                 NaN
# 591                                           NaN                 NaN
# 754    https://www.tiktok.com/@thuraya.in?lang=ar                 NaN
# ...                                           ...                 ...
# 48611                                         NaN                 NaN
# 48626                                         NaN                 NaN
# 48707                                         NaN                 NaN
# 48795                                         NaN                 NaN
# 48982         https://www.tiktok.com/@haykalah_re        haykalah.res
#
# [388 rows x 40 columns]

# %%
df.shape
# Out:
# (49008, 40)

# %%
# df.to_excel(f'all.xlsx', index=False, engine='xlsxwriter')
