# %%
import pandas as pd
import numpy as np
import json

# %%
cols_to_delete = [
    "sub",
    "imageUrl",
    "totalReviews",
    "certificationStatus",
    "activeStatus",
    "adminActiveStatus",
    "ownerAllowStatus",
    "freeLanceDocument",
    "encryptedId",
    "qrCodeUrl",
    "id",
]

social_media = [
    "Facebook",
    "Instagram",
    "Unknown",
    "Twitter",
    "Unknown",
    "AppStore",
    "PlayStore",
    "Whatsapp",
    "Telegram",
    "Website",
    "Unknown",
    "TikTok",
    "Unknown",
    "Unknown",
    "Unknown",
    "Unknown",
    "Unknown",
    "Unknown",
]

# %%
def generate_data():
    with open("new_data.jsonl", "r", encoding="utf-8") as file:
        for line in file.readlines():
            product = json.loads(line[:-1])
            for col in cols_to_delete:
                product.pop(col)
            consoles = product.pop("consoles")
            socials = {}
            if consoles:
                for c in consoles:
                    socials[social_media[c["providerType"]]] = c["url"]
                product["socialMedia"] = socials
            yield product

# %%
data = generate_data()

# %%
df = pd.json_normalize(data)

# %%
df.replace(r"\.{2,}", "", regex=True, inplace=True)

# %%
import re
from typing import List

# %%
def camel_to_title(string: str) -> str:
    pattern = re.compile(r"([A-z][a-z]+)")
    array = string.split(".")
    words = []
    for w in array:
        matches: List[str] = pattern.findall(w)
        for word in matches:
            word = word.title()
            words.append(word)

    return " ".join(words)

# %%
df.drop_duplicates(inplace=True)

# %%
df.dropna(thresh=2000, axis="columns", inplace=True)

# %%
df[df["businessType.name"] == "Real estate"]
# Out:
#                                      userId  \
# 98     bccaa119-c73a-4571-b887-1460fcbfff2a
# 113    68edee9d-2ce1-4583-8254-69229f282d06
# 353    5cbffccd-0318-4261-aae4-30ff81430a9e
# 525    605bcdb2-7778-4a9a-8a8d-7b2d8e5b0cd6
# 605    34b269c4-c8c0-4c43-9fc2-dbdbf3c4c318
# ...                                     ...
# 58773  f13d0fc4-93dc-4e9f-b73b-aa9c6f2206a6
# 58776  61485c52-7183-4725-be0f-aa5bcd96fdc7
# 58825  ae5c6637-0688-4cc0-a198-4b5e8a17a65f
# 58826  a57f4051-67b4-44fe-9e63-01ddcbc339c5
# 58858  04949a9d-de03-4499-8682-7cff3893b4ab
#
#                                          nameAr  \
# 98          مؤسسة كراء المساكن للخدمات العقارية
# 113             مؤسسة الحربي الدولية للمقاولات
# 353    المسكان العقارية لتقديم الخدمات العقارية
# 525                       ثريا للوساطة العقارية
# 605                       مجموعة هتيلز الفندقية
# ...                                         ...
# 58773                                     سهالة
# 58776              مكتب سعد مطر البلادي للعقار
# 58825                              جنى المستقبل
# 58826                              رواد المقابض
# 58858                        متوكل لمواد البناء
#
#                                           nameEn  \
# 98                                          None
# 113               Alharbi international company
# 353    AlMouskan to provide real estate services
# 525                                      THURAYA
# 605                                 Hotelz Group
# ...                                          ...
# 58773                                       Ease
# 58776                                     sadsaf
# 58825                                       None
# 58826                    Pioneers of the handles
# 58858                                       None
#
#                                              description  rating  \
# 98     نقوم بتوثيق عقود الإيجارات السكنية والتجارية و...     5.0
# 113     بناء المساجد و المدارس  في داخل المملكه وخارج...     5.0
# 353    تقديم الخدمات العقارية باحترافية بيع وشراء وتأ...     5.0
# 525    مؤسسة مختصة بالوساطة العقارية وتقديم الخدمات ا...     5.0
# 605    مجموعة فندقية في مكة المكرمة بجوار الحرم المكي...     5.0
# ...                                                  ...     ...
# 58773  نقدم جميع الخدمات العقارية\r\nالوساطة في البيع...     0.0
# 58776                                  وسيط عقاري معتمد      0.0
# 58825                         تأجير شقق مفروشة شهري سنوي     0.0
# 58826                                        مواد البناء     0.0
# 58858                                 متجر مواد بناء\r\n     0.0
#
#       otherTypeName businessType.name businessType.key  businessType.id  \
# 98             None       Real estate       RealEstate               48
# 113            None       Real estate       RealEstate               48
# 353            None       Real estate       RealEstate               48
# 525            None       Real estate       RealEstate               48
# 605            None       Real estate       RealEstate               48
# ...             ...               ...              ...              ...
# 58773          None       Real estate       RealEstate               48
# 58776          None       Real estate       RealEstate               48
# 58825          None       Real estate       RealEstate               48
# 58826          None       Real estate       RealEstate               48
# 58858          None       Real estate       RealEstate               48
#
#       businessSubType.name  ... socialMedia.Whatsapp  \
# 98                   Other  ...         966564455202
# 113                  Other  ...         966506224674
# 353                  Other  ...         966546457740
# 525     Real estate broker  ...         966583440437
# 605                  Other  ...                  NaN
# ...                    ...  ...                  ...
# 58773                Other  ...         966554421041
# 58776                Other  ...         966555546264
# 58825                Other  ...         966502008500
# 58826                Other  ...         966554710006
# 58858                Other  ...         966531558898
#
#                     socialMedia.Twitter  \
# 98        https://twitter.com/kiraa_ksa
# 113    https://twitter.com/hassan102est
# 353       https://twitter.com/almouskan
# 525    https://twitter.com/GhareebStore
# 605     https://twitter.com/HotelzGroup
# ...                                 ...
# 58773       https://twitter.com/SA_Ease
# 58776      https://twitter.com/sad11811
# 58825                               NaN
# 58826                               NaN
# 58858                               NaN
#
#                                     socialMedia.Facebook socialMedia.Telegram  \
# 98     https://www.facebook.com/%D9%85%D8%A4%D8%B3%D8...                  NaN
# 113                                                  NaN                  NaN
# 353    https://www.facebook.com/profile.php?id=100000...                  NaN
# 525                                                  NaN                  NaN
# 605                                                  NaN                  NaN
# ...                                                  ...                  ...
# 58773                                                NaN                  NaN
# 58776                                                NaN                  NaN
# 58825                                                NaN                  NaN
# 58826                                                NaN                  NaN
# 58858                                                NaN                  NaN
#
#                    socialMedia.Instagram  \
# 98                                   NaN
# 113                                  NaN
# 353                                  NaN
# 525                                  NaN
# 605    https://instagram.com/hotelzgroup
# ...                                  ...
# 58773                                NaN
# 58776                                NaN
# 58825                                NaN
# 58826                                NaN
# 58858                                NaN
#
#                            socialMedia.Website  \
# 98                    https://www.kiraa-sa.com
# 113        https://forms.gle/7yqBy3Cp47yB6PSW7
# 353    https://www.facebook.com/-431203090385/
# 525                                        NaN
# 605                        www.HotelzGroup.com
# ...                                        ...
# 58773                          https://ease.sa
# 58776                                      NaN
# 58825                     https://jana-jed.com
# 58826                 https://zid.store/pioner
# 58858              https://zid.store/materials
#
#                                socialMedia.TikTok  socialMedia.Unknown  \
# 98                                            NaN                  NaN
# 113                                           NaN                  NaN
# 353                                           NaN                  NaN
# 525    https://www.tiktok.com/@thuraya.in?lang=ar                  NaN
# 605                                           NaN                  NaN
# ...                                           ...                  ...
# 58773                                         NaN                  NaN
# 58776                                         NaN                  NaN
# 58825                                         NaN                  NaN
# 58826                                         NaN                  NaN
# 58858                                         NaN                  NaN
#
#         cr.number                              cr.name
# 98     4030381211  مؤسسة كراء المساكن للخدمات العقارية
# 113    5864525134       مؤسسة الحربي الدولية للمقاولات
# 353    4030161502               مؤسسة المسكان العقارية
# 525           NaN                                  NaN
# 605    4031086792                     شركة زي الفندقية
# ...           ...                                  ...
# 58773  4030381304         مؤسسة سهالة للخدمات العقارية
# 58776  4031062287          مكتب سعد مطر البلادي للعقار
# 58825  4030314515          مؤسسة جنى المستقبل للعقارات
# 58826  2251101132          مؤسسة رواد المقابض التجارية
# 58858  2031103441             مؤسسة متوكل لمواد البناء
#
# [543 rows x 41 columns]

# %%
df.shape
# Out:
# (58851, 41)

# %%
df.sample(50).to_excel('sample.xlsx', index=False)
